# %% [markdown]
# <a href="https://colab.research.google.com/github/updalla-apshir/machine-learning-projects/blob/main/4_2_importing_dataset_through_kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing kaggle libraray
# !pip install kaggle

# %% [markdown]
# upload your kaggle.json file

# %%
# configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing Earthquake Dataset

# %%
# API to fetech the dataset from kaggle
