# %% [markdown]
# <a href="https://colab.research.google.com/github/updalla-apshir/machine-learning-projects/blob/main/4_3_handling_missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## methods to handle missing values
# 1. Imputation
# 2. Dropping

# %%
# importing libries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/Placement_Dataset.csv')

# %%
dataset.head()

# %%
# finding null
dataset.isnull().sum()

# %% [markdown]
# ## Central Tendencies
# 1. Mean
# 2. Median
# 3. Mode

# %%
fig,ax = plt.subplots(figsize=(8,8))
sns.distplot(dataset.salary)

# %% [markdown]
# Replace the missing values with Median values

# %%
dataset['salary'].fillna(dataset['salary'].median(),inplace=True)

# %%
dataset.head()

# %%
sns.distplot(dataset['salary'])

# %%
# finding null
dataset.isnull().sum()

# %% [markdown]
# # Dropping Methond

# %%
salary_dataset = pd.read_csv('/content/Placement_Dataset.csv')

# %%
salary_dataset.shape

# %%
salary_dataset.isnull().sum()

# %%
# dropping
salary_dataset.dropna(inplace=True)

# %%
salary_dataset.shape

# %%
salary_dataset.isnull().sum()
