# %% [markdown]
# <a href="https://colab.research.google.com/github/updalla-apshir/machine-learning-projects/blob/main/4_8_Feature_extraction_of_Text_data_using_Tf_idf_Vectorizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "I love machine learning",
    "Machine learning is amazing",
    "I love Python"
]

# %%
vectorizer = TfidfVectorizer()
x = vectorizer.fit_transform(documents)

# %%
print(x)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9 stored elements and shape (3, 6)>
#   Coords	Values
#   (0, 3)	0.5773502691896257
#   (0, 4)	0.5773502691896257
#   (0, 2)	0.5773502691896257
#   (1, 4)	0.4280460350631185
#   (1, 2)	0.4280460350631185
#   (1, 1)	0.5628290964997665
#   (1, 0)	0.5628290964997665
#   (2, 3)	0.6053485081062916
#   (2, 5)	0.7959605415681652

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['amazing' 'is' 'learning' 'love' 'machine' 'python']

# %%
print(x.toarray())
# Out:
# [[0.         0.         0.57735027 0.57735027 0.57735027 0.        ]
#  [0.5628291  0.5628291  0.42804604 0.         0.42804604 0.        ]
#  [0.         0.         0.         0.60534851 0.         0.79596054]]

# %% [markdown]
# make as structured data

# %%
import pandas as pd

# %%
df = pd.DataFrame(x.toarray(),columns = vectorizer.get_feature_names_out())

# %%
print(df)
# Out:
#     amazing        is  learning      love   machine    python
# 0  0.000000  0.000000  0.577350  0.577350  0.577350  0.000000
# 1  0.562829  0.562829  0.428046  0.000000  0.428046  0.000000
# 2  0.000000  0.000000  0.000000  0.605349  0.000000  0.795961
